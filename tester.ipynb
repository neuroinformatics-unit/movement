# %% [raw]
# from movement import sample_data
# from movement.io import save_bboxes
# from movement.io.load_bboxes import from_via_tracks_file
#
# ds = from_via_tracks_file(
#     sample_data.fetch_dataset("via_tracks_single.csv")
# )
#
# save_bboxes.to_via_tracks_file(ds, "test.csv")
# save_bboxes.to_via_tracks_file(ds, "test.csv")  # should not crash
